# %% [markdown]
# # Reformating of the data from MMHS150K dataset
#
# This notebook is a part of the project to reformat the data from the MMHS150K dataset. The original dataset is in the form of a JSON file. The data is reformatted into a CSV file for easier access and manipulation. The dataset contains the following columns:
# - `index`: The unique identifier for each tweet.
# - `img_url`: The URL of the image associated with the tweet.
# - `labels`: The labels assigned to the tweet.
# - `tweet_url`: The URL of the tweet.
# - `tweet_text`: The text content of the tweet.
# - `labels_str`: The labels assigned to the tweet as a string.
# - `tweet_text_clean`: The cleaned version of the tweet text. (no URLS and mentions)
# - `img_text`: The text extracted from the image, if available. (otherwise NaN)
# - `text_in_image`: Indicates whether the image contains text or not.
# - `hate_speech`: The level of hate speech in the tweet. (from 0 to 1)
# - `binary_hate`: A binary label indicating whether the tweet contains hate speech or not. (threshold at 0.5)
# - `split`: The split of the dataset (train, test, or val).
#
# The notebook expects to find such directory structure:
# ```
# .
# ├── MMHS150K
# │   ├── MMHS150K_GT.json
# │   └── img_resized
# │   │   ├── 1114679353714016256.jpg
# │   │   ├── ...
# │   │   └── 1110368198786846720.jpg
# │   └── img_txt
# │   │   ├── 1114679353714016256.json
# │   │   ├── ...
# │   │   └── 1110368198786846720.json
# │   └── splits
# │   │   ├── train_ids.txt
# │   │   └── test_ids.txt
# │   └────── val_ids.txt
# └── reformat_data.ipynb
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
import json
import tqdm
import re

import torch
import torch.nn as nn

# %%
## Will load the text-side of the dataset, put it in a pandas dataframe and save it in a csv file
# for ease of use in the future

# Data folder
DATA_FOLDER = 'MMHS150K/MMHS150K_GT.json'
# Folder with the img_txt
IMG_TEXT_FOLDER = 'MMHS150K/img_txt/'
# Splits folder
SPLITS_FOLDER = 'MMHS150K/splits/'

## Load data
data = pd.read_json(DATA_FOLDER, orient='index', convert_dates=False, convert_axes=False)
data = data.reset_index(drop=False)
data['index'] = data['index'].astype(int)


## Clean the tweet text
# Keep only the text before https://t.co/
data['tweet_text_clean'] = data['tweet_text'].str.split('https://t.co/').str[0]
# Replace any occurence of @user with <tag>
regex_tag = r'(^|[^@\w])@(\w{1,15})\b'
data['tweet_text_clean'] = data['tweet_text_clean'].apply(lambda x: re.sub(regex_tag, '<tag>', x))


## Add the text of the image if it exists
# Number of files in the folder
n_files = len(os.listdir(IMG_TEXT_FOLDER))
# Names of the files
files = os.listdir(IMG_TEXT_FOLDER)
# Add new column in the dataset for the image text, filled with None
data['img_text'] = [None]*len(data)
# Load each file and add the text to the dataset to the corresponding index
for file in files:
    index = int(file.split('.')[0])
    
    # Open the file (json)
    with open(IMG_TEXT_FOLDER + file) as f:
        file_data = json.load(f)
                
        # Add the text to the dataset
        data.loc[data['index'] == index, 'img_text'] = file_data["img_text"]
data['text_in_image'] = data['img_text'].isna().apply(lambda x: not x)


## Add the hate_speech label
# replace the labels with a single label hateful or not
data['hate_speech'] = data.apply(lambda x: np.mean([0 if i == 0 else 1 for i in x['labels']]), axis=1)
data['binary_hate'] = data['hate_speech'].apply(lambda x: 1 if x >= 0.5 else 0)


## Add the split
# Load the splitsb
train = pd.read_csv(SPLITS_FOLDER + 'train_ids.txt', header=None)
test = pd.read_csv(SPLITS_FOLDER + 'test_ids.txt', header=None)
val = pd.read_csv(SPLITS_FOLDER + 'val_ids.txt', header=None)

# Add the split to the dataset if the index is in the split
data['split'] = 'train'
data.loc[data['index'].isin(test[0]), 'split'] = 'test'
data.loc[data['index'].isin(val[0]), 'split'] = 'val'

display(data)



## Save the dataset
data.to_csv('MMHS150K/MMHS150K.csv', index=False)
# Out:
#                       index  \
# 0       1114679353714016256
# 1       1063020048816660480
# 2       1108927368075374593
# 3       1114558534635618305
# 4       1035252480215592966
# ...                     ...
# 149818  1114170734472048640
# 149819  1110368198786846720
# 149820  1106941858540851200
# 149821  1105268309233188865
# 149822  1114653514364530691
#
#                                                   img_url     labels  \
# 0       http://pbs.twimg.com/tweet_video_thumb/D3gi9MH...  [4, 1, 3]
# 1       http://pbs.twimg.com/ext_tw_video_thumb/106301...  [5, 5, 5]
# 2          http://pbs.twimg.com/media/D2OzhzHUwAADQjd.jpg  [0, 0, 0]
# 3       http://pbs.twimg.com/ext_tw_video_thumb/111401...  [1, 0, 0]
# 4          http://pbs.twimg.com/media/Dl30pGIU8AAVGxO.jpg  [1, 0, 1]
# ...                                                   ...        ...
# 149818  http://pbs.twimg.com/tweet_video_thumb/D3ZUXNw...  [2, 5, 0]
# 149819  http://pbs.twimg.com/ext_tw_video_thumb/111036...  [0, 0, 0]
# 149820     http://pbs.twimg.com/media/D1yluGmXgAEKNG5.jpg  [0, 1, 0]
# 149821  http://pbs.twimg.com/tweet_video_thumb/D1azqiz...  [1, 0, 0]
# 149822     http://pbs.twimg.com/media/D3gLdL0W0AENzVJ.jpg  [0, 0, 3]
#
#                                                 tweet_url  \
# 0       https://twitter.com/user/status/11146793537140...
# 1       https://twitter.com/user/status/10630200488166...
# 2       https://twitter.com/user/status/11089273680753...
# 3       https://twitter.com/user/status/11145585346356...
# 4       https://twitter.com/user/status/10352524802155...
# ...                                                   ...
# 149818  https://twitter.com/user/status/11141707344720...
# 149819  https://twitter.com/user/status/11103681987868...
# 149820  https://twitter.com/user/status/11069418585408...
# 149821  https://twitter.com/user/status/11052683092331...
# 149822  https://twitter.com/user/status/11146535143645...
#
#                                                tweet_text  \
# 0            @FriskDontMiss Nigga https://t.co/cAsaLWEpue
# 1          My horses are retarded https://t.co/HYhqc6d5WN
# 2       “NIGGA ON MA MOMMA YOUNGBOY BE SPITTING REAL S...
# 3       RT xxSuGVNGxx: I ran into this HOLY NIGGA TODA...
# 4       “EVERYbody calling you Nigger now!” https://t....
# ...                                                   ...
# 149818  @svdate @gtconway3d I would just say hes Donny...
# 149819  @Cheftime_Dev congrats my nigga keep on grindi...
# 149820        My nigga big shitty https://t.co/e0snJGBgH9
# 149821  did she just say “my nigga” to Rich? &amp; she...
# 149822  This nigga Joe Budden said thanos got a galact...
#
#                                labels_str  \
# 0           [Religion, Racist, Homophobe]
# 1       [OtherHate, OtherHate, OtherHate]
# 2             [NotHate, NotHate, NotHate]
# 3              [Racist, NotHate, NotHate]
# 4               [Racist, NotHate, Racist]
# ...                                   ...
# 149818       [Sexist, OtherHate, NotHate]
# 149819        [NotHate, NotHate, NotHate]
# 149820         [NotHate, Racist, NotHate]
# 149821         [Racist, NotHate, NotHate]
# 149822      [NotHate, NotHate, Homophobe]
#
#                                          tweet_text_clean  \
# 0                                            <tag> Nigga
# 1                                 My horses are retarded
# 2       “NIGGA ON MA MOMMA YOUNGBOY BE SPITTING REAL S...
# 3       RT xxSuGVNGxx: I ran into this HOLY NIGGA TODA...
# 4                    “EVERYbody calling you Nigger now!”
# ...                                                   ...
# 149818  <tag><tag> I would just say hes Donny the retard
# 149819          <tag> congrats my nigga keep on grinding
# 149820                               My nigga big shitty
# 149821  did she just say “my nigga” to Rich? &amp; she...
# 149822  This nigga Joe Budden said thanos got a galact...
#
#                                                  img_text  text_in_image  \
# 0                                      #YOUNGERU SAVE IT            True
# 1                                                    None          False
# 2                                                    None          False
# 3                                                    None          False
# 4                                                    None          False
# ...                                                   ...            ...
# 149818                             LATE MOGIF LATE MOTIV            True
# 149819  ON AIR Elapsed Time: 05.47:18 Select Your Leve...           True
# 149820                                               None          False
# 149821                                               None          False
# 149822                                               None          False
#
#         hate_speech  binary_hate  split
# 0          1.000000            1  train
# 1          1.000000            1  train
# 2          0.000000            0  train
# 3          0.333333            0  train
# 4          0.666667            1    val
# ...             ...          ...    ...
# 149818     0.666667            1  train
# 149819     0.000000            0  train
# 149820     0.333333            0  train
# 149821     0.333333            0  train
# 149822     0.333333            0  train
#
# [149823 rows x 12 columns]

# %% [markdown]
# A second CSV is created, containing only the memes for which there is a text in the image. This dataset contains the same columns as the original dataset.

# %%
# Second version of the dataset with only tweets which have a text in the image
data2 = data[data['text_in_image']]

# Remove text_in_image column
data2 = data2.drop(columns=['text_in_image'])

display(data2)

# Save the dataset
data2.to_csv('MMHS150K/MMHS150K_text_in_image.csv', index=False)
# Out:
#                       index  \
# 0       1114679353714016256
# 6       1113920043568463874
# 7       1114588617693966336
# 8       1045809514740666370
# 10      1116702448016556035
# ...                     ...
# 149808  1056595445215059969
# 149812  1107387893541232642
# 149816  1105465552544374786
# 149818  1114170734472048640
# 149819  1110368198786846720
#
#                                                   img_url     labels  \
# 0       http://pbs.twimg.com/tweet_video_thumb/D3gi9MH...  [4, 1, 3]
# 6          http://pbs.twimg.com/media/D3VwYEKW4AYz4vk.jpg  [5, 1, 1]
# 7          http://pbs.twimg.com/media/D3fQcCCWAAIG8tO.jpg  [0, 0, 0]
# 8          http://pbs.twimg.com/media/DoN2KFmXcAAIT-Y.jpg  [3, 3, 0]
# 10      http://pbs.twimg.com/tweet_video_thumb/D39S8tb...  [0, 0, 0]
# ...                                                   ...        ...
# 149808     http://pbs.twimg.com/media/DqnH9QYVYAAKgDj.jpg  [1, 0, 1]
# 149812     http://pbs.twimg.com/media/D147aqyX0AICbzE.jpg  [0, 0, 0]
# 149816  http://pbs.twimg.com/tweet_video_thumb/D1dnDez...  [0, 1, 1]
# 149818  http://pbs.twimg.com/tweet_video_thumb/D3ZUXNw...  [2, 5, 0]
# 149819  http://pbs.twimg.com/ext_tw_video_thumb/111036...  [0, 0, 0]
#
#                                                 tweet_url  \
# 0       https://twitter.com/user/status/11146793537140...
# 6       https://twitter.com/user/status/11139200435684...
# 7       https://twitter.com/user/status/11145886176939...
# 8       https://twitter.com/user/status/10458095147406...
# 10      https://twitter.com/user/status/11167024480165...
# ...                                                   ...
# 149808  https://twitter.com/user/status/10565954452150...
# 149812  https://twitter.com/user/status/11073878935412...
# 149816  https://twitter.com/user/status/11054655525443...
# 149818  https://twitter.com/user/status/11141707344720...
# 149819  https://twitter.com/user/status/11103681987868...
#
#                                                tweet_text  \
# 0            @FriskDontMiss Nigga https://t.co/cAsaLWEpue
# 6       @WhiteHouse @realDonaldTrump Fuck ice. White s...
# 7                    Day’s a cunt https://t.co/Ie6QZReHsw
# 8                   #sissy faggot https://t.co/bm1nk8HcYO
# 10      @DefNotJerm So.... you turn to twitter for it ...
# ...                                                   ...
# 149808  New Video: Spice – Black Hypocrisy https://t.c...
# 149812  @EcholsEli Nigga Ricardo literally givin out n...
# 149816  @quisLaFlare Good luck my nigga 🤘🏾 https://t.c...
# 149818  @svdate @gtconway3d I would just say hes Donny...
# 149819  @Cheftime_Dev congrats my nigga keep on grindi...
#
#                              labels_str  \
# 0         [Religion, Racist, Homophobe]
# 6           [OtherHate, Racist, Racist]
# 7           [NotHate, NotHate, NotHate]
# 8       [Homophobe, Homophobe, NotHate]
# 10          [NotHate, NotHate, NotHate]
# ...                                 ...
# 149808        [Racist, NotHate, Racist]
# 149812      [NotHate, NotHate, NotHate]
# 149816        [NotHate, Racist, Racist]
# 149818     [Sexist, OtherHate, NotHate]
# 149819      [NotHate, NotHate, NotHate]
#
#                                          tweet_text_clean  \
# 0                                            <tag> Nigga
# 6       <tag><tag> Fuck ice. White supremacist trash. ...
# 7                                           Day’s a cunt
# 8                                          #sissy faggot
# 10      <tag> So.... you turn to twitter for it instea...
# ...                                                   ...
# 149808                New Video: Spice – Black Hypocrisy
# 149812  <tag> Nigga Ricardo literally givin out n-word...
# 149816                       <tag> Good luck my nigga 🤘🏾
# 149818  <tag><tag> I would just say hes Donny the retard
# 149819          <tag> congrats my nigga keep on grinding
#
#                                                  img_text  hate_speech  \
# 0                                      #YOUNGERU SAVE IT      1.000000
# 6       Hello, White Nationalist. Good-bye. Others wil...     1.000000
# 7       Dad's a Cunt Mum's a Cunt Nan's a Cunt Kids ar...     0.000000
# 8       EVERY SISSY GIRL SHOULD KNOW THAT MEN ARE WIZA...     0.666667
# 10                                                 SBURG      0.000000
# ...                                                   ...          ...
# 149808                                              vevo      0.666667
# 149812  Ricardo wants to grant you a free n-word pass!...     0.000000
# 149816                                     YOU CAN DO IT      0.666667
# 149818                             LATE MOGIF LATE MOTIV      0.666667
# 149819  ON AIR Elapsed Time: 05.47:18 Select Your Leve...     0.000000
#
#         binary_hate  split
# 0                 1  train
# 6                 1  train
# 7                 0  train
# 8                 1    val
# 10                0  train
# ...             ...    ...
# 149808            1  train
# 149812            0  train
# 149816            1  train
# 149818            1  train
# 149819            0  train
#
# [59252 rows x 11 columns]
